# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats
from scipy.stats import kurtosis, skew
import seaborn as sns

plt.style.use('ggplot')

# %% [markdown]
# # Stem and Leaf

# %%
marks = np.array([10,11,22,24,35,37,45,47,48,58,56,59,61,71,81,92,95])
stems = [i//10 for i in marks]
leafs = [i%10 for i in marks]

plt.stem(stems, leafs)
plt.ylabel('leafs')
plt.xlabel('stems')
plt.show()

# %% [markdown]
# # PMF (Probability Mass Function)

# %% [markdown]
# Expected value:
# $$ E(X) = \mu = \sum_i p(x_i)x_i$$

# %% [markdown]
# # CDF (Cumulative Distribution Function)

# %% [markdown]
# $$ F(X) = P(X<=x) $$

# %%
sample = [1,2,3,4,5,6]
hist = np.histogram(sample, bins=6, range=(1, 7), normed=True)
plt.step(hist[1][:-1], np.cumsum(hist[0]))
plt.title ("Die Roll -  Cumulative Distribution Function - V2");
plt.xlabel("Die Values")
plt.ylabel("Cumulative Probability")
plt.show()
# Out:
# C:\Data\Python37\lib\site-packages\ipykernel_launcher.py:2: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.

# %% [markdown]
# # PDF (Probability Density Function)

# %% [markdown]
# ## Visualizing probability Density Functions

# %% [markdown]
# - Histograms
# - Density plots
#   - Parametric methods
#   - Kernel density estimation (KDE)

# %% [markdown]
# ## Seaborn

# %%
data = pd.read_csv('../Data/weight-height.csv')
# Create two vertical subplots sharing 15% and 85% of plot space
# sharex allows sharing of axes i.e. building multiple plots on same axes
fig, (ax, ax2) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)}, figsize = (10,8) )

sns.distplot(data.Height, 
             hist=True, hist_kws={
                                  "linewidth": 2,
                                  "edgecolor" :'salmon',
                                  "alpha": 0.4, 
                                  "color":  "w",
                                  "label": "Histogram",
                                  },
             kde=True, kde_kws = {'linewidth': 3,
                                  'color': "blue",
                                  "alpha": 0.7,
                                  'label':'Kernel Density Estimation Plot'
                                 },
             fit= stats.norm, fit_kws = {'color' : 'green',
                                         'label' : 'parametric fit',
                                         "alpha": 0.7,
                                          'linewidth':3},
             ax=ax2)
ax2.set_title('Density Estimations')

sns.boxplot(x=data.Height, ax = ax,color = 'salmon')
ax.set_title('Box and Whiskers Plot')
ax2.set(ylim=(0, .08))
plt.ylim(0,0.11)
plt.legend()

# %% [markdown]
# # Gaussian / Normal distribution

# %% [markdown]
# Normal distribution is symmetrical and its mean, median and mode are equal (no skewness)
#
# 68% -> 1 std
# 95% -> 2 std
# 99% -> 3 std

# %% [markdown]
# ## Standard normal distribution

# %% [markdown]
# Standard score (z-score - how many standard deviations above or below the mean)
#
# Any normal distribution can be converted to a standard normal distribution and vice versa using this
# equation:
#
# $$\Large z=\dfrac{x-\mu}{\sigma}$$

# %% [markdown]
# # Skewness and Kurtosis

# %% [markdown]
# For univariate data $Y_1, Y_2, ..., Y_n$ the formula for **Skewness** is:
#
# $$\dfrac{\dfrac{\displaystyle\sum^n_{i=1}(Y_i-Y)^3}{n}}{s^3}$$
#
# - Between -0.5 and 0.5 -> pretty symmetrical
# - Between -1 and -0.5 (negatively skewed) or between 0.5 and 1 (positively skewed) -> moderately skewed.
# - < -1 (negatively skewed) or > than 1 (positively skewed) -> highly skewed
#
# **Kurtosis** measures outliers in the distribution
#
# For univariate data $Y_1, Y_2, \dots, Y_n$ the formula for kurtosis is:
#
# $$\dfrac{\dfrac{\displaystyle\sum^n_{i=1}(Y_i-Y)^4}{n}}{s^4}$$
#
# - Mesokurtic: around 3
# - Platykurtic: < 3
# - Leptokurtic: > 3

# %%
x_random = np.random.normal(0, 1, 10000)
plt.hist(x_random, bins='auto')
plt.show()
print(kurtosis(x_random))
print(skew(x_random))
# Out:
# -0.01161487930739069
# -0.010971493634389847
